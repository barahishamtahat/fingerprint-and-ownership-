# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread('fingerprint.jpg', 0)
ret, img = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

edges = cv2.Canny(img, 100, 200)
cv2_imshow(edges)

# Wait for a key press and then close the image window
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=409x612>

# %%
import cv2
from google.colab.patches import cv2_imshow

def preprocess_image(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    ret, img = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
    return img

def perform_verification(image_path):
    verified = True
    return verified

def main():
    image_path = '/content/fingerprint.jpg'
    fingerprint_image = preprocess_image(image_path)
    cv2_imshow(fingerprint_image)
    verification_result = perform_verification(image_path)
    if verification_result:
        print("Person is verified.")
    else:
        print("Verification failed.")
if __name__ == "__main__":
    main()
# Out:
# <PIL.Image.Image image mode=L size=409x612>
# Person is verified.
